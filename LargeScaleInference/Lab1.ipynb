# %% [markdown]
# # Practical classes
#
# All exercices will be in Python. It is important that you keep track of exercices and structure you code correctly (e.g. create funcions that you can re-use later)
#
# We will use Jupyter notebooks (formerly known as IPython). You can read the following courses for help:
# * Python and numpy: http://cs231n.github.io/python-numpy-tutorial/
# * Jupyter / IPython : http://cs231n.github.io/ipython-tutorial/
#
# To run this notebook:
# * create a directory somewhere on your filesystem
# * download the .ipynb from the course website: http://teaching.caio-corro.fr/2019-2020/TC4/
# * move the .ipynb into the directory
# * from a terminal:
#     * cd /directory/path
#     * jupyter notebook
#
# Each group must send me their work by e-mail (one mail per group):
# * complete the code with comments
# * quick answer to questions
#
# If you don't want to use the notebook, send me the python code + a PDF with plots and answers.

# %%
# import libraries

# NLTK will be used to load the data
import nltk

# matplotlib will be used to display plots
import matplotlib
import matplotlib.pyplot as plt

# in this exercise, numpy is only used to compute plotting data
import numpy as np

# So we can display plots in the notebook
# %matplotlib inline

# %% [markdown]
# # Part-of-speech tagging
#
# The goal of this exercise is to build a (really) simple **part-of-speech** (POS) tagger: given a sentence, predict the grammatical category of each word (verb, noun, etc). To this end, we introduce the following probability model: let *X* and *Y* be two random variables where *X* is an observed word and *Y* an observed tag. At test time, we will predict the most probable tag for a given word.
#
# # Data: the Brown corpus
#
# In this exercise we are going to look at the [Brown corpus](https://en.wikipedia.org/wiki/Brown_Corpus) which is a collection of texts from different domains. It has been manually annotated with POS tags.
#
# Contrary to popular belief, there is not a single way to analyze natural language texts. One usually rely on a "framework" or annotation scheme that exposes desired characteristics (see for example [Rambow, 2010](https://www.aclweb.org/anthology/N10-1049/)). In this exercise, we will us the *universal tagset* [Petrov et al, 2011](https://arxiv.org/abs/1104.2086), a simple annotation scheme that was originally proposed for multilingual natural language processing (see the [universal dependendency page about morphology](https://universaldependencies.org/u/overview/morphology.html) for more information).

# %%
# Download the Brown corpus and the annotation scheme
# This cell can be run only once on your computer
nltk.download('brown')
nltk.download('universal_tagset')
# Out:
# [nltk_data] Downloading package brown to /home/gerem/nltk_data...
# [nltk_data]   Package brown is already up-to-date!
# [nltk_data] Downloading package universal_tagset to
# [nltk_data]     /home/gerem/nltk_data...
# [nltk_data]   Package universal_tagset is already up-to-date!
# True

# %%
# Load the dataset
# the argument tagset='universal' will map the original annotation to the universal tagset
brown_data = list(nltk.corpus.brown.tagged_sents(tagset='universal'))

# %% [markdown]
# The data is structured as follows:
# * brown_data is a list of sentences
# * a sentence brown_data[i] is a list of tokens
# * each token brown_data[i][j] is a tuple of strings (word, tag)

# %%
print(type(brown_data), type(brown_data[0]), type(brown_data[0][0]))
print("Number of sentences: %i" % len(brown_data))
# Out:
# <class 'list'> <class 'list'> <class 'tuple'>
# Number of sentences: 57340

# %%
print(brown_data[0])
# Out:
# [('The', 'DET'), ('Fulton', 'NOUN'), ('County', 'NOUN'), ('Grand', 'ADJ'), ('Jury', 'NOUN'), ('said', 'VERB'), ('Friday', 'NOUN'), ('an', 'DET'), ('investigation', 'NOUN'), ('of', 'ADP'), ("Atlanta's", 'NOUN'), ('recent', 'ADJ'), ('primary', 'NOUN'), ('election', 'NOUN'), ('produced', 'VERB'), ('``', '.'), ('no', 'DET'), ('evidence', 'NOUN'), ("''", '.'), ('that', 'ADP'), ('any', 'DET'), ('irregularities', 'NOUN'), ('took', 'VERB'), ('place', 'NOUN'), ('.', '.')]

# %% [markdown]
# # 1. Data pre-processing
#
# Split the dataset into two disjoint parts:
# * *train data* that will be used to learn the probability distribution p(y | x)
# * *test data* that will be used to evaluate the model
# We use 90% of the data as train data and 10% as test data.
#
# Note that the Brown corpus is a concatenation of texts from different domains. Therefore, we need to distribute the train/test split accross the corpus: you cannot just take the first 10% of sentences as test data and the remaining ones as train data.
#
# How can you do that?

# %%
train_data = []
test_data = []

import random
random.shuffle(brown_data) # We start by shuffling the dataset to break the correlation between successive sentences
test_data = brown_data[:len(brown_data)//10]
train_data = brown_data[len(brown_data)//10:]

# %%
print("Size of the train data: %i" % len(train_data))
print("Size of the test data: %i" % len(test_data))
# Out:
# Size of the train data: 51606
# Size of the test data: 5734

# %% [markdown]
# # 2. Data visualization
#
# We now analyze the data. First we will visualize the distribution of POS tags in the train and test sets. They should be roughly similar.

# %%
# Input:
# - data: a dataset
# Output:
# a dictionnary where each key is a POS tag and the associated value is its frequency in the dataset
def compute_pos_distribution(data):
    distribution = {}
    for sentence in data:
        for word, tag in sentence:
            if tag in distribution:
                distribution[tag] += 1
            else:
                distribution[tag] = 1
    return distribution

# %%
test_pos_distribution = compute_pos_distribution(test_data)
train_pos_distribution = compute_pos_distribution(train_data)

# %%
# Display the distribution of POS tags in the train and dev sets.
# This code is an adaptation of:
# https://matplotlib.org/3.1.1/gallery/lines_bars_and_markers/barchart.html#sphx-glr-gallery-lines-bars-and-markers-barchart-py

# built the list of tags (categories)
labels = list(train_pos_distribution.keys())

# built the lists of category distributions for the 2 datasets
train_probs = [train_pos_distribution[k] for k in labels]
test_probs = [test_pos_distribution[k] for k in labels]

x = np.arange(len(labels))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots()
rects1 = ax.bar(x - width/2, train_probs, width, label='Train')
rects2 = ax.bar(x + width/2, test_probs, width, label='Dev')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_ylabel('Distribution')
ax.set_title('Distribution of POS tags')
ax.set_xticks(x)
ax.set_xticklabels(labels)
ax.legend()

fig.tight_layout()

plt.show()

# %% [markdown]
# We now look at word distribution.

# %%
# Input:
# - data: a dataset
# Output:
# a dictionnary where each key is a word and the associated value is the number of occurences of this word in the dataset
def compute_word_counts(data):
    distribution = {}
    for sentence in data:
        for word, tag in sentence:
            if word in distribution:
                distribution[word] += 1
            else:
                distribution[word] = 1
    return distribution

# %%
train_word_counts = compute_word_counts(train_data)
test_word_counts = compute_word_counts(test_data)

# %%
# Input:
# - data: a dataset
# - words: a set of words
# Output:
# the percentage of words in the dataset that are in the input set words
def compute_cover(dataset, words):
    good_words = sum(sum(1 for word, tag in sentence if word in words) for sentence in dataset)
    all_words = sum(len(sentence) for sentence in dataset)
    return good_words / all_words

# %% [markdown]
# We want to display a plot that shows the percentage of the train/test datasets that are covered with the N most frequent words.

# %%
x = list()
y_train = list()
y_dev = list()

from collections import Counter 
max_n_words = 100
train_frequent_words = [word for (word, c) in Counter(train_word_counts).most_common(max_n_words)]
test_frequent_words = [word for (word, c) in Counter(test_word_counts).most_common(max_n_words)]
for i in range(1, max_n_words):
    x.append(i)
    y_train.append(compute_cover(train_data, set(train_frequent_words[:i])))
    y_dev.append(compute_cover(test_data, set(test_frequent_words[:i])))

# %% [markdown]
# We now plot the data. What can you deduce from this plot?

# %%
fig=plt.figure(figsize=(14, 10))
plt.plot(x, y_train)
plt.plot(x, y_dev)
plt.show()

# %% [markdown]
# # Training the tagger
#
# We now train a really simple discriminative POS tagger. We will learn the distribution p(y | x) where y is a tag and x is a word.
#
# Some words in the test data may not appear in the training data. In order to be robust to unknown words, we will learn the distribution p(y | x) for words that appear 10 or more times in the training data. Words that appears less than 10 times must be mapped to the "\*\*UNK\*\*" word. p(y | \*\*UNK\*\*) will be used to classify words that did not appear in the training data.

# %%
# pos_distribution_per_word should a dict of dicts:
# keys are words (including **UNK**) and values are dicts containing the POS tag distributions.
#
# p(y | x) is then pos_distribution_per_word[x][y]

pos_distribution_per_word = {}

# We start by counting the number of times a tag appears for each word
for sentence in train_data:
    for word, tag in sentence:
        if train_word_counts[word] < 10:
            word = "**UNK**"
        if word in pos_distribution_per_word:
            tag_dis = pos_distribution_per_word[word]
            if tag in tag_dis:
                tag_dis[tag] += 1
            else:
                tag_dis[tag] = 1
        else:
            pos_distribution_per_word[word] = {tag:1}
            
# Then we normalize each distribution by dividing by the number of times each word appears
for dis in pos_distribution_per_word.values():
    word_count = sum(c for c in dis.values())
    for tag in dis:
        dis[tag] /= word_count

pos_distribution_per_word
# Out:
# {'**UNK**': {'NOUN': 0.5876762330162041,
#   'ADJ': 0.14294428429472358,
#   'VERB': 0.19043496226916304,
#   'X': 0.00897275705669956,
#   'ADV': 0.03704213850709851,
#   'PRT': 0.004801212109286607,
#   'CONJ': 0.00011806259285131,
#   'NUM': 0.024399602522604067,
#   'PRON': 0.0010920789838746174,
#   'DET': 0.0005312816678308951,
#   'ADP': 0.0019480327820466151,
#   '.': 3.9354197617103335e-05},
#  'can': {'VERB': 0.9955835962145111,
#   'NOUN': 0.0037854889589905363,
#   'X': 0.0006309148264984228},
#  'establish': {'VERB': 1.0},
#  'a': {'DET': 0.9995937436522445,
#   'NOUN': 5.078204346942921e-05,
#   'X': 0.0003554743042860045},
#  'unity': {'NOUN': 1.0},
#  'and': {'CONJ': 0.9999203250736993, 'X': 7.967492630069317e-05},
#  'of': {'ADP': 0.9999384653252108, 'X': 6.153467478924374e-05},
#  'control': {'NOUN': 0.8695652173913043, 'VERB': 0.13043478260869565},
#  ';': {'.': 1.0},
#  'This': {'DET': 1.0},
#  'third': {'ADJ': 0.9806451612903225,
#   'ADV': 0.0064516129032258064,
#   'NOUN': 0.012903225806451613},
#  'choice': {'NOUN': 0.95, 'ADJ': 0.05},
#  'was': {'VERB': 1.0},
#  'in': {'ADP': 0.9767970882620565,
#   'PRT': 0.022975432211101002,
#   'X': 0.00017060964513193814,
#   'NOUN': 5.6869881710646044e-05},
#  'fact': {'NOUN': 1.0},
#  'made': {'VERB': 0.9980372914622179, 'X': 0.001962708537782139},
#  '.': {'.': 1.0},
#  'samples': {'NOUN': 1.0},
#  'would': {'VERB': 1.0},
#  'make': {'VERB': 0.9956268221574344, 'NOUN': 0.004373177842565598},
#  'any': {'DET': 0.9922279792746114, 'ADV': 0.007772020725388601},
#  'changes': {'NOUN': 0.9203539823008849, 'VERB': 0.07964601769911504},
#  'more': {'ADV': 0.5590062111801242,
#   'ADJ': 0.44047619047619047,
#   'X': 0.0005175983436853002},
#  'readily': {'ADV': 1.0},
#  'than': {'ADP': 1.0},
#  'daily': {'ADJ': 0.42857142857142855, 'ADV': 0.5714285714285714},
#  'It': {'PRON': 1.0},
#  'is': {'VERB': 0.999889049151226, 'X': 0.00011095084877399312},
#  'Hardy': {'NOUN': 1.0},
#  'usually': {'ADV': 1.0},
#  ',': {'.': 0.9999809625342675, 'X': 1.9037465732561682e-05},
#  'but': {'CONJ': 0.9482116244411326,
#   'ADP': 0.043591654247391955,
#   'ADV': 0.00819672131147541},
#  'with': {'ADP': 0.999683644416324, 'ADV': 0.00031635558367605187},
#  'the': {'DET': 0.999946898895497, 'X': 5.310110450297366e-05},
#  'The': {'DET': 1.0},
#  'rest': {'NOUN': 0.8611111111111112, 'VERB': 0.1388888888888889},
#  'Black': {'ADJ': 0.36585365853658536, 'NOUN': 0.6341463414634146},
#  'rabbit': {'NOUN': 1.0},
#  'homes': {'NOUN': 1.0},
#  'every': {'DET': 1.0},
#  'condition': {'NOUN': 0.9876543209876543, 'VERB': 0.012345679012345678},
#  'neglect': {'NOUN': 0.6363636363636364, 'VERB': 0.36363636363636365},
#  'careful': {'ADJ': 1.0},
#  '``': {'.': 1.0},
#  'From': {'ADP': 1.0},
#  'man': {'NOUN': 0.9980970504281637, 'VERB': 0.0019029495718363464},
#  'St.': {'NOUN': 1.0},
#  'Louis': {'NOUN': 1.0},
#  "''": {'.': 1.0},
#  'Wilson': {'NOUN': 1.0},
#  'said': {'VERB': 1.0},
#  'New': {'ADJ': 1.0},
#  'ideas': {'NOUN': 1.0},
#  'were': {'VERB': 1.0},
#  'dangerous': {'ADJ': 1.0},
#  'must': {'VERB': 0.9955801104972376,
#   'NOUN': 0.0033149171270718232,
#   'X': 0.0011049723756906078},
#  'be': {'VERB': 0.9996490612388138, 'X': 0.00035093876118617303},
#  'no': {'DET': 0.8901166359729895, 'ADV': 0.10988336402701043},
#  'matter': {'NOUN': 0.9114391143911439, 'VERB': 0.08856088560885608},
#  'how': {'ADV': 1.0},
#  'her': {'DET': 0.6165011459129106, 'PRON': 0.3834988540870894},
#  'symbol': {'NOUN': 1.0},
#  '?': {'.': 0.9997649823736781, 'X': 0.00023501762632197415},
#  'Kate': {'NOUN': 1.0},
#  'asked': {'VERB': 1.0},
#  'uneasy': {'ADJ': 1.0},
#  'at': {'ADP': 1.0},
#  "girl's": {'NOUN': 1.0},
#  'dilemma': {'NOUN': 1.0},
#  'concern': {'NOUN': 0.8705882352941177, 'VERB': 0.12941176470588237},
#  'Utopia': {'NOUN': 1.0},
#  'best': {'ADJ': 0.8438538205980066,
#   'ADV': 0.15282392026578073,
#   'VERB': 0.0033222591362126247},
#  'ordering': {'NOUN': 0.9090909090909091, 'VERB': 0.09090909090909091},
#  'civil': {'ADJ': 1.0},
#  'society': {'NOUN': 1.0},
#  'In': {'ADP': 0.9993662864385298, 'PRT': 0.0006337135614702154},
#  'all': {'PRT': 0.9318555008210181, 'ADV': 0.06814449917898194},
#  'bitter': {'ADJ': 1.0},
#  'over': {'ADP': 0.687962962962963,
#   'PRT': 0.3101851851851852,
#   'ADJ': 0.001851851851851852},
#  'election': {'NOUN': 1.0},
#  'procedures': {'NOUN': 1.0},
#  'complicated': {'VERB': 1.0},
#  'numbers': {'NOUN': 0.9903846153846154, 'VERB': 0.009615384615384616},
#  'game': {'VERB': 0.008849557522123894, 'NOUN': 0.9911504424778761},
#  'that': {'ADP': 0.6280487804878049,
#   'PRON': 0.17367160278745644,
#   'DET': 0.19305313588850173,
#   'ADV': 0.005117595818815331,
#   'X': 0.00010888501742160279},
#  'East': {'NOUN': 0.31746031746031744, 'ADJ': 0.6825396825396826},
#  'West': {'NOUN': 0.5084745762711864, 'ADJ': 0.4915254237288136},
#  'played': {'VERB': 1.0},
#  'on': {'ADP': 0.9130134622022782,
#   'PRT': 0.0866413531239213,
#   'X': 0.00034518467380048324},
#  'assistant': {'ADJ': 0.23809523809523808, 'NOUN': 0.7619047619047619},
#  'theme': {'NOUN': 1.0},
#  'gentleman': {'NOUN': 1.0},
#  'from': {'ADP': 1.0},
#  'Burma': {'NOUN': 1.0},
#  'showed': {'VERB': 1.0},
#  'himself': {'PRON': 1.0},
#  'both': {'DET': 1.0},
#  'as': {'ADP': 0.8425941283794991,
#   'ADV': 0.15724000663459944,
#   'X': 0.0001658649859014762},
#  'principle': {'NOUN': 0.99, 'ADJ': 0.01},
#  'skilled': {'ADJ': 1.0},
#  'Time': {'NOUN': 1.0},
#  'magazine': {'NOUN': 1.0},
#  'reviewed': {'VERB': 1.0},
#  'it': {'PRON': 0.9998350379412735, 'PRT': 0.0001649620587264929},
#  'suggested': {'VERB': 0.9894736842105263, 'ADJ': 0.010526315789473684},
#  'Federation': {'NOUN': 1.0},
#  'Assembly': {'NOUN': 1.0},
#  'Daily': {'ADJ': 1.0},
#  'should': {'VERB': 1.0},
#  'translated': {'VERB': 1.0},
#  'into': {'ADP': 0.9987341772151899, 'X': 0.0012658227848101266},
#  'medium': {'NOUN': 0.8285714285714286, 'ADJ': 0.17142857142857143},
#  'inventory': {'NOUN': 1.0},
#  'tones': {'NOUN': 1.0},
#  'much': {'ADV': 0.4730392156862745, 'ADJ': 0.5269607843137255},
#  'smaller': {'ADJ': 1.0},
#  'commonly': {'ADV': 1.0},
#  'contrasts': {'NOUN': 0.8181818181818182, 'VERB': 0.18181818181818182},
#  'range': {'VERB': 0.08759124087591241, 'NOUN': 0.9124087591240876},
#  'along': {'ADP': 0.565625, 'ADV': 0.434375},
#  'one': {'NUM': 0.8275201226523572,
#   'NOUN': 0.1717133001149866,
#   'DET': 0.0007665772326561902},
#  'single': {'ADJ': 0.9554140127388535,
#   'NOUN': 0.03821656050955414,
#   'VERB': 0.006369426751592357},
#  'dimension': {'NOUN': 0.9285714285714286, 'VERB': 0.07142857142857142},
#  'pitch': {'NOUN': 1.0},
#  'level': {'NOUN': 0.9329896907216495,
#   'ADJ': 0.05670103092783505,
#   'VERB': 0.010309278350515464},
#  'Mr.': {'NOUN': 1.0},
#  'member': {'NOUN': 1.0},
#  'Institute': {'NOUN': 1.0},
#  'Radio': {'NOUN': 1.0},
#  'chairman': {'NOUN': 1.0},
#  'Association': {'NOUN': 1.0},
#  'Committee': {'NOUN': 1.0},
#  'At': {'ADP': 1.0},
#  'same': {'ADJ': 1.0},
#  'time': {'NOUN': 1.0},
#  'device': {'NOUN': 1.0},
#  'employed': {'VERB': 1.0},
#  'to': {'PRT': 0.5718664997193558,
#   'ADP': 0.42796079616596866,
#   'X': 8.635205733776608e-05,
#   'ADV': 4.317602866888304e-05,
#   'NOUN': 4.317602866888304e-05},
#  'reduce': {'VERB': 1.0},
#  'number': {'NOUN': 0.997624703087886, 'VERB': 0.0023752969121140144},
#  'variables': {'NOUN': 1.0},
#  'greatest': {'ADJ': 1.0},
#  'value': {'NOUN': 0.9945945945945946, 'VERB': 0.005405405405405406},
#  'attractive': {'ADJ': 1.0},
#  'features': {'NOUN': 0.9577464788732394, 'VERB': 0.04225352112676056},
#  'dynamic': {'ADJ': 0.9473684210526315, 'NOUN': 0.05263157894736842},
#  'room': {'NOUN': 0.9969418960244648, 'VERB': 0.0030581039755351682},
#  'left': {'VERB': 0.7018348623853211,
#   'ADJ': 0.15137614678899083,
#   'NOUN': 0.14678899082568808},
#  'for': {'ADP': 0.9989957318604067,
#   'ADV': 0.0006276675872457946,
#   'NOUN': 0.0003766005523474768},
#  'using': {'VERB': 0.9819819819819819, 'ADJ': 0.018018018018018018},
#  'special': {'ADJ': 0.985, 'NOUN': 0.015},
#  'problem': {'NOUN': 1.0},
#  'this': {'DET': 0.9997209042701647, 'ADV': 0.00027909572983533354},
#  'end': {'NOUN': 0.9027777777777778, 'VERB': 0.09722222222222222},
#  'Junior': {'ADJ': 0.8181818181818182, 'NOUN': 0.18181818181818182},
#  'an': {'DET': 0.996265172735761,
#   'CONJ': 0.0034235916588857764,
#   'X': 0.0003112356053532524},
#  'extremely': {'ADV': 1.0},
#  'worthy': {'ADJ': 1.0},
#  'project': {'NOUN': 0.8780487804878049, 'VERB': 0.12195121951219512},
#  'earnestly': {'ADV': 1.0},
#  'encouraged': {'VERB': 1.0},
#  '!': {'.': 1.0},
#  'their': {'DET': 1.0},
#  'second': {'ADJ': 0.9019607843137255,
#   'NOUN': 0.08169934640522876,
#   'ADV': 0.016339869281045753},
#  'child': {'NOUN': 1.0},
#  'when': {'ADV': 1.0},
#  'she': {'PRON': 1.0},
#  'finds': {'VERB': 1.0},
#  'ivory': {'NOUN': 0.7857142857142857, 'ADJ': 0.21428571428571427},
#  'by': {'ADP': 0.9890398947829899,
#   'ADV': 0.010740903112669882,
#   'X': 0.00021920210434020167},
#  'husband': {'NOUN': 1.0},
#  'mother': {'NOUN': 0.9941176470588236, 'VERB': 0.0058823529411764705},
#  'son': {'NOUN': 1.0},
#  'are': {'VERB': 1.0},
#  'revealed': {'VERB': 1.0},
#  'though': {'ADP': 0.907185628742515,
#   'ADV': 0.08682634730538923,
#   'CONJ': 0.0029940119760479044,
#   'VERB': 0.0029940119760479044},
#  'people': {'NOUN': 0.9972260748959778, 'VERB': 0.0027739251040221915},
#  'had': {'VERB': 1.0},
#  'very': {'ADV': 0.8808139534883721, 'ADJ': 0.11918604651162791},
#  'few': {'ADJ': 1.0},
#  'slaves': {'NOUN': 1.0},
#  'themselves': {'PRON': 1.0},
#  'yet': {'CONJ': 0.20553359683794467, 'ADV': 0.7944664031620553},
#  'they': {'PRON': 1.0},
#  'been': {'VERB': 1.0},
#  'pretty': {'ADV': 0.5955056179775281, 'ADJ': 0.4044943820224719},
#  'considerable': {'ADJ': 1.0},
#  'them': {'PRON': 0.9949526813880126, 'DET': 0.005047318611987382},
#  'others': {'NOUN': 1.0},
#  'diagonalizable': {'ADJ': 1.0},
#  'operator': {'NOUN': 1.0},
#  'D': {'NOUN': 1.0},
#  'nilpotent': {'ADJ': 1.0},
#  'N': {'NOUN': 1.0},
#  'determined': {'VERB': 1.0},
#  '(': {'.': 0.9959312839059674, 'X': 0.00406871609403255},
#  'A': {'NOUN': 0.08629441624365482,
#   'DET': 0.9128595600676819,
#   'X': 0.0008460236886632825},
#  ')': {'.': 0.9959677419354839, 'X': 0.004032258064516129},
#  'B': {'NOUN': 1.0},
#  'each': {'DET': 1.0},
#  'polynomial': {'NOUN': 0.9583333333333334, 'ADJ': 0.041666666666666664},
#  'T': {'NOUN': 1.0},
#  'Mike': {'NOUN': 1.0},
#  'He': {'PRON': 1.0},
#  'looking': {'VERB': 0.958904109589041,
#   'ADJ': 0.02054794520547945,
#   'NOUN': 0.02054794520547945},
#  'now': {'ADV': 1.0},
#  'Some': {'DET': 0.9735449735449735, 'ADV': 0.026455026455026454},
#  'Catholic': {'ADJ': 0.9875, 'NOUN': 0.0125},
#  'priests': {'NOUN': 1.0},
#  'lecture': {'VERB': 0.14285714285714285, 'NOUN': 0.8571428571428571},
#  'there': {'ADV': 0.2807017543859649, 'PRT': 0.7192982456140351},
#  'Stevie': {'NOUN': 1.0},
#  'heard': {'VERB': 1.0},
#  'these': {'DET': 1.0},
#  'words': {'NOUN': 1.0},
#  'many': {'ADJ': 0.9680589680589681,
#   'ADV': 0.009828009828009828,
#   'PRT': 0.022113022113022112},
#  'times': {'NOUN': 0.983402489626556,
#   'ADP': 0.012448132780082987,
#   'VERB': 0.004149377593360996},
#  'occasion': {'NOUN': 1.0},
#  'caused': {'VERB': 1.0},
#  'him': {'PRON': 1.0},
#  'tremble': {'VERB': 1.0},
#  'And': {'CONJ': 1.0},
#  '--': {'.': 0.99968, 'X': 0.00032},
#  'mail': {'NOUN': 0.868421052631579, 'VERB': 0.13157894736842105},
#  'What': {'DET': 0.9764705882352941, 'PRON': 0.023529411764705882},
#  'about': {'ADP': 0.6987421383647798,
#   'ADV': 0.2893081761006289,
#   'PRT': 0.011320754716981131,
#   'X': 0.0006289308176100629},
#  'your': {'DET': 1.0},
#  'girl': {'NOUN': 1.0},
#  'you': {'PRON': 1.0},
#  'going': {'VERB': 0.9914772727272727, 'NOUN': 0.008522727272727272},
#  'kill': {'VERB': 0.9818181818181818, 'NOUN': 0.01818181818181818},
#  'woman': {'NOUN': 0.9948979591836735, 'VERB': 0.00510204081632653},
#  'who': {'PRON': 1.0},
#  'willing': {'ADJ': 1.0},
#  'give': {'VERB': 0.9940476190476191, 'NOUN': 0.005952380952380952},
#  'love': {'NOUN': 0.765625, 'VERB': 0.234375},
#  'faith': {'NOUN': 1.0},
#  'anything': {'NOUN': 1.0},
#  'else': {'ADV': 1.0},
#  'could': {'VERB': 1.0},
#  'Well': {'PRT': 0.8307692307692308,
#   'ADV': 0.16153846153846155,
#   'ADJ': 0.007692307692307693},
#  'Jesus': {'PRT': 0.08928571428571429, 'NOUN': 0.9107142857142857},
#  'drunk': {'ADJ': 0.65625, 'NOUN': 0.3125, 'VERB': 0.03125},
#  "I'll": {'PRT': 1.0},
#  'get': {'VERB': 1.0},
#  'out': {'ADP': 0.21587819467101685,
#   'PRT': 0.7835780315388798,
#   'ADV': 0.000543773790103317},
#  'here': {'ADV': 1.0},
#  'soon': {'ADV': 1.0},
#  'I': {'PRON': 0.9989249623736831, 'NOUN': 0.0010750376263169211},
#  'possibly': {'ADV': 1.0},
#  "don't": {'VERB': 1.0},
#  'want': {'VERB': 0.9722222222222222, 'NOUN': 0.027777777777777776},
#  'see': {'VERB': 1.0},
#  'like': {'ADP': 0.8,
#   'VERB': 0.17207207207207206,
#   'ADJ': 0.027927927927927927},
#  'Maybe': {'ADV': 1.0},
#  'beat': {'VERB': 0.55,
#   'NOUN': 0.38333333333333336,
#   'ADJ': 0.06666666666666667},
#  'old': {'ADJ': 1.0},
#  'after': {'ADP': 0.9864864864864865,
#   'ADV': 0.012162162162162163,
#   'PRT': 0.0013513513513513514},
#  'two': {'NUM': 1.0},
#  'daughters': {'NOUN': 1.0},
#  'Mrs.': {'NOUN': 1.0},
#  'F.': {'NOUN': 1.0},
#  'Miss': {'NOUN': 1.0},
#  'Harris': {'NOUN': 1.0},
#  'enlisted': {'VERB': 1.0},
#  'men': {'NOUN': 1.0},
#  'he': {'PRON': 0.9996608444972019, 'X': 0.0003391555027980329},
#  'officer': {'NOUN': 1.0},
#  'whose': {'DET': 1.0},
#  'wife': {'NOUN': 1.0},
#  'tried': {'VERB': 1.0},
#  'lot': {'NOUN': 1.0},
#  'plenty': {'NOUN': 0.8260869565217391,
#   'ADV': 0.15217391304347827,
#   'ADJ': 0.021739130434782608},
#  'reason': {'NOUN': 0.985781990521327, 'VERB': 0.014218009478672985},
#  'dislike': {'VERB': 0.5833333333333334, 'NOUN': 0.4166666666666667},
#  'spirit': {'NOUN': 1.0},
#  'real': {'ADJ': 0.9375, 'ADV': 0.0625},
#  'explanation': {'NOUN': 1.0},
#  'our': {'DET': 1.0},
#  'achievement': {'NOUN': 1.0},
#  'award': {'NOUN': 0.9117647058823529, 'VERB': 0.08823529411764706},
#  'August': {'NOUN': 1.0},
#  '13': {'NUM': 1.0},
#  'Senator': {'NOUN': 1.0},
#  'Paul': {'NOUN': 1.0},
#  'Douglas': {'NOUN': 1.0},
#  'example': {'NOUN': 1.0},
#  'Both': {'DET': 1.0},
#  'Social': {'ADJ': 1.0},
#  'Democrats': {'NOUN': 1.0},
#  'gained': {'VERB': 1.0},
#  '22': {'NUM': 1.0},
#  'seats': {'NOUN': 1.0},
#  'new': {'ADJ': 1.0},
#  'Free': {'ADJ': 1.0},
#  'picked': {'VERB': 1.0},
#  'up': {'PRT': 0.9054134443783463, 'ADP': 0.09458655562165377},
#  '23': {'NUM': 1.0},
#  'will': {'VERB': 0.9537688442211055, 'NOUN': 0.04623115577889447},
#  'insist': {'VERB': 1.0},
#  'before': {'ADP': 0.8309692671394799,
#   'ADV': 0.16784869976359337,
#   'X': 0.001182033096926714},
#  'enter': {'VERB': 1.0},
#  'government': {'NOUN': 1.0},
#  'Ekstrohm': {'NOUN': 1.0},
#  'his': {'DET': 0.994515852613539,
#   'PRON': 0.005141388174807198,
#   'X': 0.00034275921165381317},
#  'way': {'NOUN': 0.9900249376558603, 'ADV': 0.00997506234413965},
#  'outside': {'ADV': 0.30538922155688625,
#   'ADP': 0.40718562874251496,
#   'ADJ': 0.17964071856287425,
#   'NOUN': 0.10778443113772455},
#  'scanned': {'VERB': 1.0},
#  'Who': {'PRON': 1.0},
#  'told': {'VERB': 1.0},
#  'do': {'VERB': 1.0},
#  'family': {'NOUN': 1.0},
#  'assign': {'VERB': 1.0},
#  'full-time': {'ADJ': 0.9523809523809523, 'ADV': 0.047619047619047616},
#  'maid': {'NOUN': 1.0},
#  'keeping': {'VERB': 0.9423076923076923, 'NOUN': 0.057692307692307696},
#  'eye': {'NOUN': 1.0},
#  'boy': {'NOUN': 0.9952153110047847, 'PRT': 0.004784688995215311},
#  'These': {'DET': 1.0},
#  'human': {'NOUN': 0.12121212121212122, 'ADJ': 0.8787878787878788},
#  'beings': {'NOUN': 1.0},
#  'whom': {'PRON': 0.9921875, 'X': 0.0078125},
#  'God': {'NOUN': 0.9924528301886792, 'PRT': 0.007547169811320755},
#  'chosen': {'VERB': 1.0},
#  'tone': {'NOUN': 0.9857142857142858, 'VERB': 0.014285714285714285},
#  "Hardy's": {'NOUN': 1.0},
#  'natural': {'ADJ': 1.0},
#  'voice': {'NOUN': 1.0},
#  'not': {'ADV': 1.0},
#  'surprising': {'ADJ': 0.5714285714285714, 'VERB': 0.42857142857142855},
#  '1912': {'NUM': 1.0},
#  '-': {'ADP': 0.927536231884058, 'X': 0.07246376811594203},
#  'poems': {'NOUN': 1.0},
#  'consistently': {'ADV': 1.0},
#  'She': {'PRON': 1.0},
#  "didn't": {'VERB': 1.0},
#  'sound': {'VERB': 0.12903225806451613,
#   'ADJ': 0.22580645161290322,
#   'NOUN': 0.6397849462365591,
#   'ADV': 0.005376344086021506},
#  'pale': {'ADJ': 0.9803921568627451, 'NOUN': 0.0196078431372549},
#  'When': {'ADV': 1.0},
#  "we'd": {'PRT': 1.0},
#  'finished': {'VERB': 1.0},
#  'regular': {'ADJ': 1.0},
#  'rounds': {'NOUN': 1.0},
#  'Pete': {'NOUN': 1.0},
#  'pointed': {'VERB': 0.9701492537313433, 'ADJ': 0.029850746268656716},
#  'me': {'PRON': 0.9990566037735849, 'X': 0.0009433962264150943},
#  'toward': {'ADP': 1.0},
#  'small': {'ADJ': 1.0},
#  'ward': {'NOUN': 1.0},
#  'floor': {'NOUN': 1.0},
#  'Keep': {'VERB': 1.0},
#  'occupied': {'VERB': 1.0},
#  'point': {'NOUN': 0.9365994236311239, 'VERB': 0.06340057636887608},
#  'bored': {'VERB': 1.0},
#  'life': {'NOUN': 1.0},
#  'truly': {'ADV': 1.0},
#  'find': {'VERB': 0.9912790697674418, 'NOUN': 0.00872093023255814},
#  'final': {'ADJ': 0.9925925925925926, 'NOUN': 0.007407407407407408},
#  'days': {'NOUN': 1.0},
#  'years': {'NOUN': 0.9988193624557261, 'X': 0.0011806375442739079},
#  'lives': {'NOUN': 0.6417910447761194, 'VERB': 0.3582089552238806},
#  'sweet': {'ADJ': 1.0},
#  'By': {'ADP': 0.9837837837837838, 'ADV': 0.016216216216216217},
#  'political': {'ADJ': 1.0},
#  'economic': {'ADJ': 1.0},
#  'standards': {'NOUN': 1.0},
#  'justified': {'VERB': 1.0},
#  'doing': {'VERB': 0.9722222222222222, 'NOUN': 0.027777777777777776},
#  'so': {'ADV': 0.7634880803011292, 'ADP': 0.23651191969887075},
#  "Let's": {'VERB': 1.0},
#  'play': {'VERB': 0.5449101796407185, 'NOUN': 0.4550898203592814},
#  "'em": {'PRON': 1.0},
#  'Jack': {'NOUN': 1.0},
#  'rising': {'VERB': 1.0},
#  'where': {'ADV': 1.0},
#  'sat': {'VERB': 1.0},
#  'ground': {'NOUN': 0.9141104294478528, 'VERB': 0.08588957055214724},
#  'off': {'PRT': 0.7621527777777778, 'ADP': 0.2378472222222222},
#  'overall': {'NOUN': 0.18181818181818182, 'ADJ': 0.8181818181818182},
#  'skin': {'NOUN': 1.0},
#  'smooth': {'ADJ': 0.8888888888888888, 'VERB': 0.1111111111111111},
#  'cheeks': {'NOUN': 1.0},
#  'lips': {'NOUN': 1.0},
#  'looked': {'VERB': 1.0},
#  'if': {'ADP': 0.9992509363295881, 'X': 0.000749063670411985},
#  'shock': {'NOUN': 0.9333333333333333, 'VERB': 0.06666666666666667},
#  'Gorton': {'NOUN': 1.0},
#  'appeared': {'VERB': 1.0},
#  'however': {'ADV': 1.0},
#  'what': {'DET': 1.0},
#  'have': {'VERB': 1.0},
#  'charged': {'VERB': 1.0},
#  'court': {'NOUN': 0.981651376146789, 'VERB': 0.01834862385321101},
#  'leave': {'VERB': 0.9485714285714286, 'NOUN': 0.05142857142857143},
#  'colony': {'NOUN': 1.0},
#  'within': {'ADP': 0.9725085910652921, 'ADV': 0.027491408934707903},
#  'fourteen': {'NUM': 1.0},
#  'You': {'PRON': 1.0},
#  'accused': {'VERB': 1.0},
#  'religious': {'ADJ': 1.0},
#  'remain': {'VERB': 1.0},
#  'loyal': {'ADJ': 1.0},
#  'Many': {'ADJ': 0.979381443298969, 'PRT': 0.020618556701030927},
#  'other': {'ADJ': 1.0},
#  'vehicles': {'NOUN': 1.0},
#  'products': {'NOUN': 1.0},
#  'contribute': {'VERB': 1.0},
#  'some': {'DET': 0.9866666666666667, 'ADV': 0.013333333333333334},
#  'information': {'NOUN': 1.0},
#  'Bob': {'NOUN': 1.0},
#  'Fogg': {'NOUN': 1.0},
#  'already': {'ADV': 1.0},
#  'historical': {'ADJ': 1.0},
#  'first': {'ADJ': 0.7651309846431797, 'ADV': 0.23486901535682023},
#  'air': {'NOUN': 1.0},
#  'history': {'NOUN': 1.0},
#  'Its': {'DET': 1.0},
#  'massive': {'ADJ': 1.0},
#  'contours': {'NOUN': 1.0},
#  'simple': {'ADJ': 1.0},
#  'need': {'NOUN': 0.44936708860759494, 'VERB': 0.5506329113924051},
#  'since': {'ADP': 0.9376558603491272, 'ADV': 0.06234413965087282},
#  'always': {'ADV': 1.0},
#  'incomplete': {'ADJ': 1.0},
#  'complete': {'VERB': 0.10493827160493827, 'ADJ': 0.8950617283950617},
#  "O'Banion": {'NOUN': 1.0},
#  'vicious': {'ADJ': 1.0},
#  'Market': {'NOUN': 1.0},
#  'Street': {'NOUN': 1.0},
#  'gang': {'NOUN': 0.8947368421052632, 'VERB': 0.10526315789473684},
#  'became': {'VERB': 1.0},
#  'singing': {'VERB': 0.7073170731707317, 'NOUN': 0.2926829268292683},
#  'waiter': {'NOUN': 1.0},
#  'low': {'ADJ': 0.8951048951048951,
#   'ADV': 0.09090909090909091,
#   'NOUN': 0.013986013986013986},
#  'dive': {'NOUN': 0.85, 'VERB': 0.15},
#  'North': {'ADJ': 0.6666666666666666, 'NOUN': 0.3333333333333333},
#  'Clark': {'NOUN': 1.0},
#  'customers': {'NOUN': 1.0},
#  'money': {'NOUN': 1.0},
#  'being': {'VERB': 0.96, 'NOUN': 0.0384, 'X': 0.0016},
#  'thrown': {'VERB': 1.0},
#  'corn': {'NOUN': 1.0},
#  'field': {'NOUN': 0.9907834101382489, 'VERB': 0.009216589861751152},
#  'great': {'ADJ': 0.977818853974122, 'ADV': 0.022181146025878003},
#  'green': {'ADJ': 0.7738095238095238, 'NOUN': 0.2261904761904762},
#  'deep': {'ADJ': 0.8522727272727273, 'ADV': 0.14772727272727273},
#  'acres': {'NOUN': 1.0},
#  'rolled': {'VERB': 1.0},
#  'sea': {'NOUN': 0.972972972972973, 'VERB': 0.02702702702702703},
#  'beyond': {'ADP': 0.9452054794520548, 'ADV': 0.0547945205479452},
#  'fence': {'NOUN': 1.0},
#  'grounds': {'NOUN': 1.0},
#  'To': {'PRT': 0.5963541666666666, 'ADP': 0.4036458333333333},
#  'support': {'VERB': 0.3128834355828221, 'NOUN': 0.6871165644171779},
#  'large': {'ADJ': 0.9779874213836478,
#   'NOUN': 0.006289308176100629,
#   'ADV': 0.015723270440251572},
#  'Hamilton': {'NOUN': 1.0},
#  'went': {'VERB': 1.0},
#  'back': {'ADV': 0.7659327925840093,
#   'ADJ': 0.027809965237543453,
#   'NOUN': 0.17960602549246812,
#   'VERB': 0.026651216685979143},
#  'law': {'NOUN': 1.0},
#  'spell': {'NOUN': 0.75, 'VERB': 0.25},
#  'public': {'ADJ': 0.6584699453551912, 'NOUN': 0.34153005464480873},
#  'service': {'NOUN': 0.9821428571428571, 'VERB': 0.017857142857142856},
#  'car': {'NOUN': 1.0},
#  'license': {'NOUN': 0.9696969696969697, 'VERB': 0.030303030303030304},
#  'breakfast': {'NOUN': 1.0},
#  'till': {'ADP': 0.9767441860465116, 'VERB': 0.023255813953488372},
#  'phone': {'NOUN': 0.9166666666666666, 'VERB': 0.08333333333333333},
#  'rang': {'VERB': 1.0},
#  'making': {'VERB': 0.9177489177489178, 'NOUN': 0.08225108225108226},
#  "mother's": {'NOUN': 1.0},
#  'shake': {'VERB': 0.8571428571428571, 'NOUN': 0.14285714285714285},
#  'excitement': {'NOUN': 1.0},
#  'appears': {'VERB': 1.0},
#  'dominant': {'ADJ': 1.0},
#  'tendency': {'NOUN': 1.0},
#  'early': {'ADJ': 0.7119205298013245, 'ADV': 0.28807947019867547},
#  'tales': {'NOUN': 1.0},
#  'or': {'CONJ': 0.9997319753417314, 'X': 0.0002680246582685607},
#  'even': {'ADV': 0.9443826473859844,
#   'VERB': 0.030033370411568408,
#   'ADJ': 0.024471635150166853,
#   'X': 0.0011123470522803114},
#  'surface': {'NOUN': 0.9615384615384616, 'ADJ': 0.038461538461538464},
#  'symbolic': {'ADJ': 1.0},
#  'present': {'ADJ': 0.6071428571428571,
#   'NOUN': 0.1130952380952381,
#   'VERB': 0.10714285714285714,
#   'ADV': 0.17261904761904762},
#  'crop': {'NOUN': 1.0},
#  'cars': {'NOUN': 1.0},
#  'American': {'ADJ': 0.9361702127659575, 'NOUN': 0.06382978723404255},
#  'humor': {'NOUN': 0.9318181818181818, 'VERB': 0.06818181818181818},
#  'later': {'ADV': 0.8490566037735849, 'ADJ': 0.1509433962264151},
#  'missing': {'VERB': 0.967741935483871, 'NOUN': 0.03225806451612903},
#  'part': {'NOUN': 0.9928741092636579, 'VERB': 0.007125890736342043},
#  'found': {'VERB': 1.0},
#  'together': {'ADV': 1.0},
#  'evidence': {'NOUN': 0.9943181818181818, 'VERB': 0.005681818181818182},
#  'fully': {'ADV': 1.0},
#  'ancient': {'ADJ': 0.9821428571428571, 'NOUN': 0.017857142857142856},
#  'circle': {'NOUN': 0.9629629629629629, 'VERB': 0.037037037037037035},
#  'came': {'VERB': 1.0},
#  'nearer': {'ADV': 0.5714285714285714,
#   'ADJ': 0.2857142857142857,
#   'ADP': 0.14285714285714285},
#  'However': {'ADV': 1.0},
#  'while': {'ADP': 0.8552123552123552,
#   'NOUN': 0.14092664092664092,
#   'VERB': 0.003861003861003861},
#  'cell': {'NOUN': 1.0},
#  'trial': {'NOUN': 1.0},
#  'theft': {'NOUN': 1.0},
#  'Barco': {'NOUN': 1.0},
#  'fit': {'NOUN': 0.19402985074626866,
#   'VERB': 0.7014925373134329,
#   'ADJ': 0.1044776119402985},
#  'apprehension': {'NOUN': 1.0},
#  'attempt': {'NOUN': 0.75, 'VERB': 0.25},
#  'take': {'VERB': 0.9922779922779923, 'NOUN': 0.007722007722007722},
#  'own': {'ADJ': 0.9711815561959655, 'VERB': 0.02881844380403458},
#  'half': {'PRT': 0.8739130434782608,
#   'NOUN': 0.05217391304347826,
#   'ADV': 0.07391304347826087},
#  'Century': {'NOUN': 1.0},
#  'architect': {'NOUN': 1.0},
#  'Michelangelo': {'NOUN': 1.0},
#  'designed': {'VERB': 1.0},
#  'help': {'VERB': 0.6806083650190115,
#   'NOUN': 0.3155893536121673,
#   'PRT': 0.0038022813688212928},
#  'dome': {'NOUN': 1.0},
#  'How': {'ADV': 1.0},
#  'earth': {'NOUN': 1.0},
#  'manage': {'VERB': 1.0},
#  'Britain': {'NOUN': 1.0},
#  'until': {'ADP': 1.0},
#  'recently': {'ADV': 1.0},
#  'areas': {'NOUN': 1.0},
#  'enthusiasm': {'NOUN': 1.0},
#  'wedding': {'NOUN': 1.0},
#  'students': {'NOUN': 1.0},
#  'Christian': {'NOUN': 0.096, 'ADJ': 0.904},
#  '16': {'NUM': 1.0},
#  'There': {'PRT': 0.9521963824289406, 'ADV': 0.04780361757105943},
#  'drawing': {'NOUN': 0.3142857142857143, 'VERB': 0.6857142857142857},
#  'eyes': {'NOUN': 1.0},
#  'flash': {'VERB': 0.35294117647058826, 'NOUN': 0.6470588235294118},
#  'guests': {'NOUN': 1.0},
#  'integration': {'NOUN': 1.0},
#  'congregations': {'NOUN': 1.0},
#  'nature': {'NOUN': 1.0},
#  'Protestant': {'ADJ': 0.9347826086956522, 'NOUN': 0.06521739130434782},
#  'development': {'NOUN': 0.9964028776978417, 'X': 0.0035971223021582736},
#  'wave': {'NOUN': 0.95, 'VERB': 0.05},
#  'flame': {'NOUN': 0.75, 'VERB': 0.25},
#  'through': {'ADP': 0.9366197183098591, 'PRT': 0.06338028169014084},
#  'reached': {'VERB': 1.0},
#  'friend': {'NOUN': 1.0},
#  'entrance': {'NOUN': 1.0},
#  'then': {'ADV': 0.9817007534983854,
#   'ADJ': 0.016146393972012917,
#   'ADP': 0.002152852529601722},
#  'slowed': {'VERB': 1.0},
#  'walk': {'NOUN': 0.32954545454545453, 'VERB': 0.6704545454545454},
#  'uniform': {'NOUN': 0.46938775510204084, 'ADJ': 0.5306122448979592},
#  'also': {'ADV': 1.0},
#  'lights': {'NOUN': 0.9772727272727273, 'VERB': 0.022727272727272728},
#  'city': {'NOUN': 1.0},
#  'port': {'NOUN': 0.8181818181818182, 'ADJ': 0.18181818181818182},
#  'wall': {'NOUN': 0.9921259842519685, 'VERB': 0.007874015748031496},
#  'shore': {'NOUN': 0.9487179487179487,
#   'VERB': 0.02564102564102564,
#   'ADV': 0.02564102564102564},
#  'guide': {'VERB': 0.5142857142857142, 'NOUN': 0.4857142857142857},
#  'open': {'ADJ': 0.7907801418439716,
#   'ADV': 0.024822695035460994,
#   'VERB': 0.1702127659574468,
#   'NOUN': 0.014184397163120567},
#  'shoes': {'NOUN': 1.0},
#  'finish': {'NOUN': 0.42857142857142855, 'VERB': 0.5714285714285714},
#  'collar': {'NOUN': 0.8571428571428571, 'VERB': 0.14285714285714285},
#  'bow': {'NOUN': 0.8333333333333334, 'VERB': 0.16666666666666666},
#  'throat': {'NOUN': 1.0},
#  'has': {'VERB': 0.9995471014492754, 'X': 0.0004528985507246377},
#  'its': {'DET': 1.0},
#  'rhythms': {'NOUN': 1.0},
#  'multiple': {'ADJ': 1.0},
#  'once': {'ADV': 0.8703703703703703, 'ADP': 0.12962962962962962},
#  'us': {'PRON': 1.0},
#  'York': {'NOUN': 1.0},
#  'walked': {'VERB': 1.0},
#  'away': {'ADV': 1.0},
#  'hear': {'VERB': 1.0},
#  'taxi': {'NOUN': 1.0},
#  'although': {'ADP': 1.0},
#  '1960': {'NUM': 1.0},
#  'explosive': {'ADJ': 0.9333333333333333, 'NOUN': 0.06666666666666667},
#  'character': {'NOUN': 1.0},
#  'population': {'NOUN': 1.0},
#  'growth': {'NOUN': 1.0},
#  'Then': {'ADV': 0.9661538461538461,
#   'ADJ': 0.03076923076923077,
#   'X': 0.003076923076923077},
#  'fell': {'VERB': 0.9876543209876543, 'ADJ': 0.012345679012345678},
#  'pattern': {'NOUN': 0.98989898989899, 'VERB': 0.010101010101010102},
#  ':': {'.': 0.9876007439553627,
#   'ADP': 0.011779293242405457,
#   'NOUN': 0.0006199628022318661},
#  'scratching': {'VERB': 1.0},
#  'nose': {'NOUN': 0.9818181818181818, 'VERB': 0.01818181818181818},
#  'rain': {'NOUN': 0.9824561403508771, 'VERB': 0.017543859649122806},
#  'October': {'NOUN': 1.0},
#  'little': {'ADJ': 0.8502824858757062, 'ADV': 0.1497175141242938},
#  'Fort': {'NOUN': 0.9487179487179487, 'VERB': 0.05128205128205128},
#  'present-day': {'ADJ': 1.0},
#  '100': {'NUM': 1.0},
#  'Khrushchev': {'NOUN': 1.0},
#  'inevitable': {'ADJ': 1.0},
#  'decay': {'NOUN': 0.9166666666666666, 'VERB': 0.08333333333333333},
#  'capitalism': {'NOUN': 1.0},
#  'favorable': {'ADJ': 1.0},
#  'peaceful': {'ADJ': 1.0},
#  'coexistence': {'NOUN': 1.0},
#  'above': {'ADP': 0.6386554621848739,
#   'ADJ': 0.07142857142857142,
#   'ADV': 0.28991596638655465},
#  'Berlin': {'NOUN': 1.0},
#  'German': {'ADJ': 0.5949367088607594, 'NOUN': 0.4050632911392405},
#  'problems': {'NOUN': 1.0},
#  'settled': {'VERB': 1.0},
#  'which': {'DET': 0.9996870109546165, 'X': 0.00031298904538341156},
#  'established': {'VERB': 1.0},
#  '1958': {'NUM': 1.0},
#  'group': {'NOUN': 0.9911764705882353, 'VERB': 0.008823529411764706},
#  'activity': {'NOUN': 1.0},
#  'Department': {'NOUN': 1.0},
#  'Pennsylvania': {'NOUN': 1.0},
#  'State': {'NOUN': 1.0},
#  'University': {'NOUN': 1.0},
#  'Park': {'NOUN': 1.0},
#  'chief': {'ADJ': 0.6714285714285714, 'NOUN': 0.32857142857142857},
#  'characteristic': {'NOUN': 0.35, 'ADJ': 0.65},
#  'experience': {'NOUN': 0.9354838709677419, 'VERB': 0.06451612903225806},
#  'mode': {'NOUN': 0.9523809523809523, 'X': 0.047619047619047616},
#  'past': {'NOUN': 0.3237704918032787,
#   'ADJ': 0.4344262295081967,
#   'ADP': 0.21311475409836064,
#   'ADV': 0.028688524590163935},
#  'Sometimes': {'ADV': 1.0},
#  'streetcar': {'NOUN': 1.0},
#  'late': {'ADV': 0.2721518987341772, 'ADJ': 0.7278481012658228},
#  'fallout': {'NOUN': 1.0},
#  'rapidly': {'ADV': 1.0},
#  'House': {'NOUN': 1.0},
#  'happily': {'ADV': 1.0},
#  'engagement': {'NOUN': 1.0},
#  'Got': {'VERB': 1.0},
#  'tend': {'VERB': 1.0},
#  'quick': {'ADV': 0.109375, 'ADJ': 0.875, 'NOUN': 0.015625},
#  'assured': {'VERB': 1.0},
#  'De': {'NOUN': 0.7014925373134329, 'X': 0.29850746268656714},
#  'La': {'NOUN': 0.4444444444444444, 'X': 0.5555555555555556},
#  'commander': {'NOUN': 1.0},
#  'Alabama': {'NOUN': 1.0},
#  'post': {'NOUN': 0.8846153846153846,
#   'ADP': 0.057692307692307696,
#   'X': 0.019230769230769232,
#   'VERB': 0.038461538461538464},
#  'friendship': {'NOUN': 1.0},
#  'natives': {'NOUN': 1.0},
#  'able': {'ADJ': 1.0},
#  'look': {'VERB': 0.7363636363636363, 'NOUN': 0.2636363636363636},
#  'upon': {'ADV': 0.09813084112149532, 'ADP': 0.9018691588785047},
#  'British': {'NOUN': 0.1523809523809524, 'ADJ': 0.8476190476190476},
#  'poor': {'ADJ': 1.0},
#  'Graham': {'NOUN': 1.0},
#  'recognized': {'VERB': 1.0},
#  'baseball': {'NOUN': 1.0},
#  'William': {'NOUN': 1.0},
#  'J.': {'NOUN': 1.0},
#  'Memorial': {'ADJ': 0.875, 'NOUN': 0.125},
#  'armed': {'VERB': 1.0},
#  'numerous': {'ADJ': 1.0},
#  'competing': {'VERB': 1.0},
#  'media': {'NOUN': 1.0},
#  'cards': {'NOUN': 1.0},
#  'processed': {'VERB': 1.0},
#  'standard': {'ADJ': 0.6823529411764706, 'NOUN': 0.3176470588235294},
#  'card': {'NOUN': 1.0},
#  'equipment': {'NOUN': 1.0},
#  'including': {'ADP': 0.9662162162162162, 'VERB': 0.033783783783783786},
#  'computer': {'NOUN': 1.0},
#  'shouted': {'VERB': 1.0},
#  'Therefore': {'ADV': 1.0},
#  'only': {'ADV': 0.7797297297297298, 'ADJ': 0.22027027027027027},
#  'question': {'NOUN': 0.9342105263157895, 'VERB': 0.06578947368421052},
#  'honor': {'NOUN': 0.7818181818181819, 'VERB': 0.21818181818181817},
#  'death': {'NOUN': 1.0},
#  'Soviet': {'NOUN': 1.0},
#  'state': {'NOUN': 0.9629629629629629, 'VERB': 0.037037037037037035},
#  'Club': {'NOUN': 1.0},
#  'winter': {'NOUN': 1.0},
#  'races': {'NOUN': 1.0},
#  'Nov.': {'NOUN': 1.0},
#  '5': {'NUM': 1.0},
#  'et': {'X': 0.96, 'VERB': 0.04},
#  'show': {'NOUN': 0.2625, 'VERB': 0.7375},
#  'Boston': {'NOUN': 1.0},
#  'Manhattan': {'NOUN': 1.0},
#  'reach': {'VERB': 0.8602150537634409, 'NOUN': 0.13978494623655913},
#  'Pittsburgh': {'NOUN': 1.0},
#  'primarily': {'ADV': 1.0},
#  'presence': {'NOUN': 1.0},
#  'bronchial': {'ADJ': 1.0},
#  'artery': {'NOUN': 1.0},
#  'closely': {'ADV': 1.0},
#  'following': {'VERB': 0.8578947368421053,
#   'NOUN': 0.07894736842105263,
#   'ADP': 0.06315789473684211},
#  'pulmonary': {'ADJ': 1.0},
#  'members': {'NOUN': 1.0},
#  "President's": {'NOUN': 1.0},
#  'staff': {'NOUN': 0.978021978021978, 'VERB': 0.02197802197802198},
#  'gathered': {'VERB': 1.0},
#  'around': {'ADP': 0.5734406438631791, 'ADV': 0.42655935613682094},
#  'tent': {'NOUN': 1.0},
#  'listening': {'VERB': 1.0},
#  'watching': {'VERB': 0.9682539682539683, 'NOUN': 0.031746031746031744},
#  'attention': {'NOUN': 1.0},
#  'given': {'VERB': 0.9970674486803519, 'X': 0.002932551319648094},
#  'young': {'ADJ': 0.996875, 'NOUN': 0.003125},
#  'seated': {'VERB': 1.0},
#  'audience': {'NOUN': 1.0},
#  'deeper': {'ADJ': 0.8333333333333334, 'ADV': 0.16666666666666666},
#  'wonder': {'NOUN': 0.41509433962264153,
#   'VERB': 0.5660377358490566,
#   'ADJ': 0.018867924528301886},
#  'miracle': {'NOUN': 1.0},
#  'accomplished': {'VERB': 0.9767441860465116, 'ADJ': 0.023255813953488372},
#  'decades': {'NOUN': 1.0},
#  'rather': {'ADP': 0.334375, 'ADV': 0.65, 'PRT': 0.015625},
#  'centuries': {'NOUN': 1.0},
#  'pool': {'NOUN': 0.9662921348314607, 'VERB': 0.033707865168539325},
#  'far': {'ADV': 0.9135135135135135, 'ADJ': 0.08648648648648649},
#  'house': {'NOUN': 0.9745762711864406, 'VERB': 0.025423728813559324},
#  'high': {'ADV': 0.06295399515738499,
#   'ADJ': 0.9128329297820823,
#   'NOUN': 0.024213075060532687},
#  'hill': {'NOUN': 1.0},
#  'One': {'NUM': 0.8181818181818182, 'NOUN': 0.18181818181818182},
#  'good': {'ADJ': 0.9069423929098966,
#   'NOUN': 0.07828655834564253,
#   'ADV': 0.014771048744460856},
#  'indication': {'NOUN': 1.0},
#  "men's": {'NOUN': 1.0},
#  'personalities': {'NOUN': 1.0},
#  'reacted': {'VERB': 1.0},
#  'meeting': {'VERB': 0.18604651162790697, 'NOUN': 0.813953488372093},
#  'heroes': {'NOUN': 1.0},
#  'social': {'ADJ': 0.9969040247678018, 'NOUN': 0.0030959752321981426},
#  'analysis': {'NOUN': 1.0},
#  'reflects': {'VERB': 1.0},
#  'search': {'NOUN': 0.8852459016393442, 'VERB': 0.11475409836065574},
#  'truth': {'NOUN': 1.0},
#  'certainty': {'NOUN': 1.0},
#  'regularly': {'ADV': 1.0},
#  'scheduled': {'VERB': 1.0},
#  'hour': {'NOUN': 1.0},
#  'set': {'VERB': 0.787292817679558, 'NOUN': 0.212707182320442},
#  'aside': {'ADV': 1.0},
#  'introduction': {'NOUN': 1.0},
#  'contemporary': {'ADJ': 0.9166666666666666, 'NOUN': 0.08333333333333333},
#  'musical': {'ADJ': 0.9722222222222222, 'NOUN': 0.027777777777777776},
#  'scene': {'NOUN': 1.0},
#  'vacation': {'NOUN': 0.9767441860465116, 'VERB': 0.023255813953488372},
#  'seemed': {'VERB': 1.0},
#  'idea': {'NOUN': 1.0},
#  'last': {'ADJ': 0.8996478873239436,
#   'VERB': 0.03697183098591549,
#   'ADV': 0.04929577464788732,
#   'NOUN': 0.014084507042253521},
#  'week': {'NOUN': 1.0},
#  'doctor': {'NOUN': 1.0},
#  'prescribed': {'VERB': 1.0},
#  'trying': {'VERB': 0.9583333333333334, 'ADJ': 0.041666666666666664},
#  'say': {'VERB': 0.9612756264236902,
#   'PRT': 0.029612756264236904,
#   'NOUN': 0.00683371298405467,
#   'X': 0.002277904328018223},
#  'started': {'VERB': 1.0},
#  'fight': {'NOUN': 0.5697674418604651, 'VERB': 0.43023255813953487},
#  'expression': {'NOUN': 1.0},
#  'luck': {'NOUN': 1.0},
#  'prayer': {'NOUN': 1.0},
#  'pilot': {'NOUN': 0.9411764705882353, 'VERB': 0.058823529411764705},
#  'plane': {'NOUN': 0.9904761904761905, 'VERB': 0.009523809523809525},
#  'return': {'VERB': 0.4049079754601227,
#   'NOUN': 0.5828220858895705,
#   'ADJ': 0.012269938650306749},
#  'objective': {'NOUN': 0.5555555555555556, 'ADJ': 0.4444444444444444},
#  'chapter': {'NOUN': 1.0},
#  'clarify': {'VERB': 1.0},
#  'distinctions': {'NOUN': 1.0},
#  'between': {'ADP': 0.9984825493171472, 'ADV': 0.0015174506828528073},
#  'theory': {'NOUN': 1.0},
#  'training': {'VERB': 0.4198473282442748, 'NOUN': 0.5801526717557252},
#  'concepts': {'NOUN': 1.0},
#  'critical': {'ADJ': 1.0},
#  'fuel': {'NOUN': 1.0},
#  'provide': {'VERB': 1.0},
#  'extra': {'ADJ': 0.9512195121951219, 'ADV': 0.04878048780487805},
#  'performance': {'NOUN': 1.0},
#  'aircraft': {'NOUN': 1.0},
#  'particularly': {'ADV': 1.0},
#  'heavy': {'ADJ': 1.0},
#  'bombers': {'NOUN': 1.0},
#  'If': {'ADP': 1.0},
#  'Red': {'NOUN': 0.31343283582089554, 'ADJ': 0.6865671641791045},
#  'Handley': {'NOUN': 1.0},
#  'hurry': {'VERB': 0.4666666666666667, 'NOUN': 0.5333333333333333},
#  'hang': {'VERB': 1.0},
#  'pictures': {'NOUN': 0.98, 'VERB': 0.02},
#  'Confederate': {'ADJ': 1.0},
#  'Constitution': {'NOUN': 1.0},
#  'Five': {'NUM': 1.0},
#  'tests': {'NOUN': 1.0},
#  'conducted': {'VERB': 1.0},
#  'cover': {'NOUN': 0.4050632911392405, 'VERB': 0.5949367088607594},
#  'ice': {'NOUN': 1.0},
#  'Additional': {'ADJ': 1.0},
#  'courses': {'NOUN': 1.0},
#  'added': {'VERB': 1.0},
#  'cooperative': {'ADJ': 0.9375, 'NOUN': 0.0625},
#  'programs': {'NOUN': 1.0},
#  'worked': {'VERB': 1.0},
#  'industry': {'NOUN': 1.0},
#  'basic': {'ADJ': 1.0},
#  'facilities': {'NOUN': 1.0},
#  'program': {'NOUN': 0.9847094801223242,
#   'VERB': 0.012232415902140673,
#   'X': 0.0030581039755351682},
#  'actually': {'ADV': 1.0},
#  'occurred': {'VERB': 1.0},
#  'seldom': {'ADV': 1.0},
#  'important': {'ADJ': 1.0},
#  'generation': {'NOUN': 1.0},
#  'feels': {'VERB': 1.0},
#  'For': {'ADP': 1.0},
#  'something': {'NOUN': 1.0},
#  'openly': {'ADV': 1.0},
#  'current': {'ADJ': 0.797752808988764, 'NOUN': 0.20224719101123595},
#  'orchestra': {'NOUN': 1.0},
#  'solid': {'ADJ': 0.8955223880597015, 'NOUN': 0.1044776119402985},
#  'musician': {'NOUN': 1.0},
#  'plays': {'VERB': 0.5172413793103449, 'NOUN': 0.4827586206896552},
#  'Gross': {'NOUN': 0.717948717948718, 'ADJ': 0.28205128205128205},
#  'story': {'NOUN': 1.0},
#  'never': {'ADV': 1.0},
#  'practically': {'ADV': 1.0},
#  'whole': {'ADJ': 0.8303249097472925, 'NOUN': 0.16967509025270758},
#  'line': {'NOUN': 0.9884169884169884, 'VERB': 0.011583011583011582},
#  'nineteenth': {'ADJ': 1.0},
#  'century': {'NOUN': 1.0},
#  'English': {'ADJ': 0.5423728813559322, 'NOUN': 0.4576271186440678},
#  'critics': {'NOUN': 1.0},
#  'nearly': {'ADV': 1.0},
#  'writers': {'NOUN': 1.0},
#  'position': {'NOUN': 0.9861111111111112, 'VERB': 0.013888888888888888},
#  'those': {'DET': 1.0},
#  'less': {'ADJ': 0.5297157622739018, 'ADV': 0.4702842377260982},
#  'accuracy': {'NOUN': 1.0},
#  'called': {'VERB': 1.0},
#  'Oh': {'PRT': 1.0},
#  'Perhaps': {'ADV': 1.0},
#  'world': {'NOUN': 1.0},
#  'advanced': {'VERB': 1.0},
#  'diplomatic': {'ADJ': 1.0},
#  'papers': {'NOUN': 1.0},
#  'planes': {'NOUN': 1.0},
#  'Kennedy': {'NOUN': 1.0},
#  'administration': {'NOUN': 1.0},
#  'file': {'VERB': 0.4393939393939394, 'NOUN': 0.5606060606060606},
#  'effect': {'NOUN': 0.9282051282051282, 'VERB': 0.07179487179487179},
#  'interests': {'NOUN': 0.972972972972973, 'VERB': 0.02702702702702703},
#  'things': {'NOUN': 1.0},
#  'happen': {'VERB': 1.0},
#  'switched': {'VERB': 1.0},
#  'ceiling': {'NOUN': 1.0},
#  'light': {'NOUN': 0.7835051546391752,
#   'ADJ': 0.18900343642611683,
#   'VERB': 0.027491408934707903},
#  'stable': {'NOUN': 0.42857142857142855, 'ADJ': 0.5714285714285714},
#  'boys': {'NOUN': 1.0},
#  'Because': {'ADP': 0.6153846153846154, 'ADV': 0.38461538461538464},
#  'soul': {'NOUN': 1.0},
#  'filled': {'VERB': 1.0},
#  'functions': {'NOUN': 0.9090909090909091, 'VERB': 0.09090909090909091},
#  'Him': {'PRON': 1.0},
#  'Af': {'NOUN': 0.9988789237668162, 'X': 0.0011210762331838565},
#  'my': {'DET': 0.9990636704119851, 'PRT': 0.0009363295880149813},
#  'thought': {'VERB': 0.7913043478260869, 'NOUN': 0.20869565217391303},
#  'possibilities': {'NOUN': 1.0},
#  'ballet': {'NOUN': 0.96, 'X': 0.04},
#  'wanted': {'VERB': 1.0},
#  'producer': {'NOUN': 1.0},
#  'well': {'ADV': 0.9202363367799113,
#   'PRT': 0.029542097488921712,
#   'ADJ': 0.0206794682422452,
#   'NOUN': 0.023633677991137372,
#   'VERB': 0.005908419497784343},
#  'dance': {'VERB': 0.21794871794871795, 'NOUN': 0.782051282051282},
#  'reporters': {'NOUN': 1.0},
#  'brushed': {'VERB': 1.0},
#  'customary': {'ADJ': 1.0},
#  'bore': {'VERB': 0.8235294117647058, 'NOUN': 0.17647058823529413},
#  'central': {'ADJ': 1.0},
#  'forgot': {'VERB': 1.0},
#  'lyrics': {'NOUN': 1.0},
#  'Now': {'ADV': 1.0},
#  'tell': {'VERB': 1.0},
#  'ball': {'NOUN': 1.0},
#  'player': {'NOUN': 1.0},
#  'Somehow': {'ADV': 1.0},
#  'terrible': {'ADJ': 0.975, 'X': 0.025},
#  'die': {'VERB': 0.8135593220338984,
#   'X': 0.06779661016949153,
#   'NOUN': 0.11864406779661017},
#  'knowledge': {'NOUN': 1.0},
#  'Lord': {'NOUN': 1.0},
#  'probably': {'ADV': 1.0},
#  'suffer': {'VERB': 1.0},
#  'murder': {'NOUN': 0.9375, 'VERB': 0.0625},
#  'go': {'VERB': 0.9981515711645101, 'NOUN': 0.0018484288354898336},
#  'Kent': {'NOUN': 1.0},
#  'Most': {'ADJ': 0.9381443298969072, 'ADV': 0.061855670103092786},
#  'fingers': {'NOUN': 1.0},
#  'hand': {'NOUN': 0.9842931937172775, 'VERB': 0.015706806282722512},
#  'burned': {'VERB': 1.0},
#  'asleep': {'ADV': 0.8846153846153846, 'ADJ': 0.11538461538461539},
#  'cigarette': {'NOUN': 1.0},
#  'Chapter': {'NOUN': 1.0},
#  '10': {'NUM': 1.0},
#  'raise': {'VERB': 0.9302325581395349, 'NOUN': 0.06976744186046512},
#  'dancer': {'NOUN': 1.0},
#  'personal': {'ADJ': 1.0},
#  'self': {'NOUN': 1.0},
#  'relating': {'VERB': 1.0},
#  'larger': {'ADJ': 1.0},
#  'orbit': {'NOUN': 0.9375, 'VERB': 0.0625},
#  'During': {'ADP': 1.0},
#  'months': {'NOUN': 1.0},
#  'prison': {'NOUN': 1.0},
#  'camp': {'NOUN': 0.9821428571428571, 'VERB': 0.017857142857142856},
#  'abstract': {'ADJ': 0.8571428571428571,
#   'NOUN': 0.03571428571428571,
#   'VERB': 0.10714285714285714},
#  'images': {'NOUN': 1.0},
#  'vanished': {'VERB': 1.0},
#  'mind': {'NOUN': 0.8837209302325582, 'VERB': 0.11627906976744186},
#  'caught': {'VERB': 1.0},
#  'driving': {'VERB': 0.8809523809523809, 'NOUN': 0.11904761904761904},
#  'day': {'NOUN': 1.0},
#  'sentence': {'NOUN': 1.0},
#  'pronounced': {'VERB': 1.0},
#  'warning': {'NOUN': 0.4, 'VERB': 0.6},
#  'Texas': {'NOUN': 1.0},
#  'Education': {'NOUN': 1.0},
#  'schools': {'NOUN': 1.0},
#  'deaf': {'ADJ': 1.0},
#  'counties': {'NOUN': 1.0},
#  'require': {'VERB': 1.0},
#  'children': {'NOUN': 1.0},
#  '6': {'NUM': 1.0},
#  'age': {'NOUN': 0.9898477157360406,
#   'X': 0.005076142131979695,
#   'VERB': 0.005076142131979695},
#  'attend': {'VERB': 1.0},
#  'older': {'ADJ': 1.0},
#  'ones': {'NOUN': 1.0},
#  'residential': {'ADJ': 1.0},
#  'School': {'NOUN': 1.0},
#  'too': {'ADV': 1.0},
#  "Russia's": {'NOUN': 1.0},
#  'leading': {'VERB': 1.0},
#  'fat': {'ADJ': 0.803921568627451, 'NOUN': 0.19607843137254902},
#  "haven't": {'VERB': 1.0},
#  'baby': {'NOUN': 1.0},
#  'knew': {'VERB': 1.0},
#  'rifles': {'NOUN': 1.0},
#  'watched': {'VERB': 1.0},
#  'Castro': {'NOUN': 1.0},
#  'handling': {'VERB': 0.42424242424242425, 'NOUN': 0.5757575757575758},
#  'enemies': {'NOUN': 1.0},
#  'precisely': {'ADV': 1.0},
#  'happened': {'VERB': 1.0},
#  'Puerto': {'NOUN': 1.0},
#  'arrived': {'VERB': 1.0},
#  'thousands': {'NOUN': 1.0},
#  'bitterness': {'NOUN': 1.0},
#  'thus': {'ADV': 1.0},
#  'write': {'VERB': 1.0},
#  'fought': {'VERB': 1.0},
#  'down': {'ADP': 0.21546261089987326,
#   'PRT': 0.7807351077313055,
#   'ADJ': 0.0012674271229404308,
#   'VERB': 0.0012674271229404308,
#   'NOUN': 0.0012674271229404308},
#  'streets': {'NOUN': 1.0},
#  'Palfrey': {'NOUN': 1.0},
#  'place': {'VERB': 0.10548523206751055, 'NOUN': 0.8945147679324894},
#  'Negro': {'NOUN': 1.0},
#  'Community': {'NOUN': 1.0},
#  'better': {'ADJ': 0.5810055865921788,
#   'ADV': 0.40502793296089384,
#   'VERB': 0.013966480446927373},
#  'attempts': {'NOUN': 0.8064516129032258, 'VERB': 0.1935483870967742},
#  'rebels': {'NOUN': 0.9090909090909091, 'VERB': 0.09090909090909091},
#  'may': {'VERB': 0.9982964224872232,
#   'NOUN': 0.0008517887563884157,
#   'X': 0.0008517887563884157},
#  'try': {'VERB': 0.9739130434782609, 'NOUN': 0.02608695652173913},
#  'ends': {'VERB': 0.21052631578947367, 'NOUN': 0.7894736842105263},
#  'November': {'NOUN': 1.0},
#  '7': {'NUM': 0.9767441860465116, 'NOUN': 0.023255813953488372},
#  'Be': {'VERB': 0.9666666666666667, 'PRT': 0.03333333333333333},
#  'friends': {'NOUN': 1.0},
#  'Two': {'NUM': 1.0},
#  'hands': {'NOUN': 1.0},
#  'Mexican': {'NOUN': 0.18181818181818182, 'ADJ': 0.8181818181818182},
#  'named': {'VERB': 1.0},
#  'kid': {'NOUN': 0.9795918367346939, 'VERB': 0.02040816326530612},
#  'known': {'VERB': 1.0},
#  'trick': {'NOUN': 1.0},
#  'riding': {'VERB': 0.9714285714285714, 'NOUN': 0.02857142857142857},
#  'night': {'NOUN': 1.0},
#  'herd': {'NOUN': 0.8947368421052632, 'VERB': 0.10526315789473684},
#  'march': {'NOUN': 0.5833333333333334, 'VERB': 0.4166666666666667},
#  '1961': {'NUM': 1.0},
#  'Columbus': {'NOUN': 1.0},
#  'Ohio': {'NOUN': 1.0},
#  'site': {'NOUN': 1.0},
#  'Fourth': {'ADJ': 0.8571428571428571, 'ADV': 0.14285714285714285},
#  'Control': {'NOUN': 1.0},
#  'Science': {'NOUN': 1.0},
#  'All': {'PRT': 0.759493670886076, 'ADV': 0.24050632911392406},
#  'ever': {'ADV': 1.0},
#  'free': {'ADJ': 0.918918918918919,
#   'VERB': 0.04054054054054054,
#   'ADV': 0.04054054054054054},
#  'country': {'NOUN': 1.0},
#  'south': {'NOUN': 0.9454545454545454,
#   'ADJ': 0.01818181818181818,
#   'ADV': 0.03636363636363636},
#  'Good': {'ADJ': 1.0},
#  'Hanover': {'NOUN': 1.0},
#  '2:36': {'NUM': 1.0},
#  'everything': {'NOUN': 1.0},
#  'sale': {'NOUN': 1.0},
#  'cannot': {'VERB': 1.0},
#  'bought': {'VERB': 1.0},
#  'temptation': {'NOUN': 1.0},
#  'elements': {'NOUN': 1.0},
#  'score': {'NOUN': 0.8627450980392157, 'VERB': 0.13725490196078433},
#  'view': {'NOUN': 0.8957055214723927, 'VERB': 0.10429447852760736},
#  'literature': {'NOUN': 1.0},
#  'moral': {'ADJ': 0.9618320610687023, 'NOUN': 0.03816793893129771},
#  'without': {'ADP': 1.0},
#  'explicit': {'ADJ': 1.0},
#  'methods': {'NOUN': 1.0},
#  'searching': {'VERB': 0.9473684210526315, 'NOUN': 0.05263157894736842},
#  'protected': {'VERB': 1.0},
#  'Soon': {'ADV': 1.0},
#  'tree': {'NOUN': 1.0},
#  'voices': {'NOUN': 1.0},
#  'inside': {'ADP': 0.4897959183673469,
#   'NOUN': 0.10884353741496598,
#   'ADV': 0.35374149659863946,
#   'ADJ': 0.047619047619047616},
#  'makes': {'VERB': 0.9798657718120806, 'NOUN': 0.020134228187919462},
#  'work': {'NOUN': 0.762043795620438, 'VERB': 0.23795620437956205},
#  ...}

# %% [markdown]
# What is percentage of words that have a single tag associated with it, i.e. words x such that there exists a tag for which p(y | x) = 1?

# %%
single_tag_count = sum(1 for word in pos_distribution_per_word if len(pos_distribution_per_word[word]) == 1)
single_tag_count / len(pos_distribution_per_word)
# Out:
# 0.7572897761645493

# %% [markdown]
# What is percentage of words have a tag with a probability greater the 90%, i.e. words x such that there exists a tag for which p(y | x) > 0.9?

# %%
big_tag_count = sum(1 for word in pos_distribution_per_word if max(pos_distribution_per_word[word].values()) > 0.9)
big_tag_count / len(pos_distribution_per_word)
# Out:
# 0.8661826981246219

# %% [markdown]
# # Evaluating the model
#
# To evaluate the model, we perform maximum a posteriori classification on the test data:
# 1. for each word in the test data, predict the most probable tag under the p(y | x) distribution
# 2. the accuracy the the number of correctly predicted tags divided by the number of words in the test data
#
# What is the accuracy of the model on test data?
#
# How does it performs comparatively to a model that would have performed a priori classification? (you can look at the POS distribution plot above)

# %%
import operator
good_predictions = 0
n_predictions = 0
for sentence in test_data:
    for word, tag in sentence:
        if word not in train_word_counts or train_word_counts[word] < 10: 
            word = "**UNK**"
        predicted_tag = max(pos_distribution_per_word[word].items(), key=operator.itemgetter(1))[0]
        if predicted_tag == tag:
            good_predictions += 1
        n_predictions += 1
good_predictions / n_predictions
# Out:
# 0.9170828310659549
