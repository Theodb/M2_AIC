# %%
import matplotlib.image as mpimg
import numpy as np
img = plt.imread("barbara.jpg").astype(float)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-3-93d7c5c9ffbc> in <module>
#       1 import matplotlib.image as mpimg
#       2 import numpy as np
# ----> 3 img = plt.imread("barbara.jpg").astype(float)
#
# NameError: name 'plt' is not defined

# %%
# %load_ext nbtutor
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-2-a6137b2532dd> in <module>
# ----> 1 get_ipython().run_line_magic('load_ext', 'nbtutor')
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\interactiveshell.py in run_line_magic(self, magic_name, line, _stack_depth)
#    2305                 kwargs['local_ns'] = sys._getframe(stack_depth).f_locals
#    2306             with self.builtin_trap:
# -> 2307                 result = fn(*args, **kwargs)
#    2308             return result
#    2309
#
# <C:\ProgramData\Anaconda3\lib\site-packages\decorator.py:decorator-gen-65> in load_ext(self, module_str)
#
# C:\ProgramData\Anaconda3\lib\site-packages\IPython\core\magic.py in <lambda>(f, *a, **k)
#     185     # but it's overkill for just that one bit of state.
#     186     def magic_deco(arg):
# --> 187         call = lambda f, *a, **k: f(*a, **k)
#     188
# ...

# %%
import matplotlib.pyplot as plt
plt.imshow(img, plt.cm.gray)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).

# %%
epsilon=1e-5
f= np.fft.fft2(img)
fshift = np.fft.fftshift(f)
magnitude_spectrum = 20*np.log(np.abs(fshift))

plt.subplot(121),plt.imshow(img, cmap = 'gray')
plt.subplot(122),plt.imshow(magnitude_spectrum, cmap = 'gray')
# Out:
# C:\ProgramData\Anaconda3\lib\site-packages\ipykernel_launcher.py:4: RuntimeWarning: divide by zero encountered in log
#   after removing the cwd from sys.path.
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# (<matplotlib.axes._subplots.AxesSubplot at 0x1aa8c397da0>,
#  <matplotlib.image.AxesImage at 0x1aa8ca00320>)

# %%
plt.imshow(img, plt.cm.gray)

# %%
import skimage
import numpy as np
import matplotlib.pyplot as plt
im = plt.imread ('barbara.jpg')
im = skimage.img_as_float(im)
plt.figure()
plt.imshow(im,plt.cm.gray)

# %%
from scipy import fftpack
im_fft = fftpack.fft2(im)

def plot_spectrum(im_fft):
    from matplotlib.colors import LogNorm
    plt.imshow(np.abs(im_fft), norm=LogNorm(vmin=5))
    plt.colorbar()
plt.figure()    
plot_spectrum(im_fft)
plt.imshow(im_fft)
# Out:
# Clipping input data to the valid range for imshow with RGB data ([0..1] for floats or [0..255] for integers).
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-51-dfdcbea52cce> in <module>
#       8 plt.figure()
#       9 plot_spectrum(im_fft)
# ---> 10 plt.imshow(im_fft)
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\pyplot.py in imshow(X, cmap, norm, aspect, interpolation, alpha, vmin, vmax, origin, extent, shape, filternorm, filterrad, imlim, resample, url, data, **kwargs)
#    2697         filternorm=filternorm, filterrad=filterrad, imlim=imlim,
#    2698         resample=resample, url=url, **({"data": data} if data is not
# -> 2699         None else {}), **kwargs)
#    2700     sci(__ret)
#    2701     return __ret
#
# C:\ProgramData\Anaconda3\lib\site-packages\matplotlib\__init__.py in inner(ax, data, *args, **kwargs)
# ...

# %%
from __future__ import division

import numpy as np
import scipy as scp
import pylab as pyl
import matplotlib.pyplot as plt

from nt_toolbox.general import *
from nt_toolbox.signal import *

import warnings
warnings.filterwarnings('ignore')

# %matplotlib inline
# %load_ext autoreload
# %autoreload 2
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
n0 = 512
m = rescale(load_image("barbara.jpg", n0))

# %%
n0=int(n/2)
imageplot(M[n0-25:n0+25,n0-25:n0+25])

# %%
plt.figure(figsize = (8,8))
imageplot(m, 'Image')
imageplot(-m, '-image', [1,2,1])

# %%
F= pyl.fft2(m)/n0

# %%
from pylab import linalg

print("Energy of Image:   %f" %linalg.norm(m))
print("Energy of Fourier: %f" %linalg.norm(F))
# Out:
# Energy of Image:   247.586093
# Energy of Fourier: 990.344371

# %%
L=pyl.fftshift(np.log(abs(F) +1e-1))

# %%
plt.figure(figsize = (5,5))
imageplot(L, 'log(Fourier)')

# %%
mzoom=imageplot(m[n0//2-32:n0//2+32, n0//2-32:n0//2+32])

# %%
F= pyl.fft2(mzoom)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-117-fe854367ceb2> in <module>
# ----> 1 F= pyl.fft2(mzoom)
#
# C:\ProgramData\Anaconda3\lib\site-packages\mkl_fft\_numpy_fft.py in fft2(a, s, axes, norm)
#     865     """
#     866
# --> 867     return fftn(a, s=s, axes=axes, norm=norm)
#     868
#     869
#
# C:\ProgramData\Anaconda3\lib\site-packages\mkl_fft\_numpy_fft.py in fftn(a, s, axes, norm)
#     674
#     675     """
# --> 676     output = mkl_fft.fftn(a, s, axes)
#     677     if _unitary(norm):
#     678         output *= 1 / sqrt(_tot_size(output, axes))
#
# mkl_fft\_pydfti.pyx in mkl_fft._pydfti.fftn()
#
# mkl_fft\_pydfti.pyx in mkl_fft._pydfti._fftnd_impl()
#
# mkl_fft\_pydfti.pyx in mkl_fft._pydfti._iter_fftnd()
#
# mkl_fft\_pydfti.pyx in mkl_fft._pydfti._init_nd_shape_and_axes()
#
# ValueError: axes exceeds dimensionality of input

# %%
from os import path
from pydub import AudioSegment

# convert wav to mp3                                                            
sound = AudioSegment.from_mp3('string1.mp3')
sound.export('string.wav', format="wav")
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-115-ef4ce4ce3e6a> in <module>
#       3
#       4 # convert wav to mp3
# ----> 5 sound = AudioSegment.from_mp3('string1.mp3')
#       6 sound.export('string.wav', format="wav")
#
# C:\ProgramData\Anaconda3\lib\site-packages\pydub\audio_segment.py in from_mp3(cls, file, parameters)
#     714     @classmethod
#     715     def from_mp3(cls, file, parameters=None):
# --> 716         return cls.from_file(file, 'mp3', parameters=parameters)
#     717
#     718     @classmethod
#
# C:\ProgramData\Anaconda3\lib\site-packages\pydub\audio_segment.py in from_file(cls, file, format, codec, parameters, **kwargs)
#     663             stdin_data = file.read()
#     664
# --> 665         info = mediainfo_json(orig_file)
#     666         if info:
#     667             audio_streams = [x for x in info['streams']
#
# ...

# %%
from nt_toolbox.load_sound import *

n = 1024*16
s = 3 #number of sounds
p = 2 #number of micros

x = np.zeros([n,3])
x[:,0] = load_sound("string1.wav",n)
x[:,1] = load_sound("string2.wav",n)
x[:,2] = load_sound("string3.wav",n)

# %%
x = x/np.tile(np.std(x,0),(n,1))

# %%
plt.figure(figsize = (10,10))

for i in range(s):
    plt.subplot(s, 1, i+1)
    plt.plot(x[:, i])
    plt.xlim(0,n)
    plt.title("Source #%i" %(i+1))

# %%
import scipy.io.wavfile

samplerate1, data1 = scipy.io.wavfile.read("string1.wav")
samplerate2, data2 = scipy.io.wavfile.read("string2.wav")
samplerate3, data3 = scipy.io.wavfile.read("string3.wav")
